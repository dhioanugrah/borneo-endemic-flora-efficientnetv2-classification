# %% [markdown]
# # Skripsi Dhio — Klasifikasi Flora Endemik Kalimantan
#
# **Perubahan dari V9 :**
# - menghilangkan early stopping
# - menghilangkan learning rate schedule dan weight decay
#
# Struktur Drive:
# ```
# MyDrive/
# └─ Database Skripsi Dhio/
#    ├─ Dataset Mentah/
#    │  ├─ Spesies_A/  (100+ citra mentah)
#    │  ├─ Spesies_B/
#    │  └─ ...
#    └─ Dataset/
# ```

# %% [markdown]
# ## 0) Runtime & GPU

# %%
# Pastikan runtime GPU aktif (Runtime → Change runtime type → GPU)
import tensorflow as tf
print("TF version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1) Install KerasCV (untuk RandAugment)

# %%
# !pip install keras-cv
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-cv) (26.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras-cv) (2025.11.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (from keras-cv) (4.9.9)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (0.1.16)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (3.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.10)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.8.3)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (4.3.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.29.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (1.17.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (3.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.1.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (0.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.4.6)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2026.2.25)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->keras-core->keras-cv) (26.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (2.20.0)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets->keras-cv) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.73.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 43.3 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 65.8 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %% [markdown]
# ## 2) Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3) Konfigurasi path (Sesuai Drive Dhio)

# %%
# === KONFIGURASI ===
PROJECT_DIR = "/content/drive/MyDrive/Database_Skripsi_Dhio"
DATASET_RAW = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra"
DATASET     = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"

DO_SPLIT = True

import os
os.makedirs(PROJECT_DIR, exist_ok=True)
# %cd $PROJECT_DIR
print("Project dir:", PROJECT_DIR)
print("Raw dataset:", DATASET_RAW)
print("Split out   :", DATASET)
# Out:
# /content/drive/MyDrive/Database_Skripsi_Dhio
# Project dir: /content/drive/MyDrive/Database_Skripsi_Dhio
# Raw dataset: /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra
# Split out   : /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random

# %% [markdown]
# ## 4) Script Split 60/40 secara random

# %%
# %%writefile split_dataset.py
import os, shutil, random, glob, sys

def ensure_dir(p):
    os.makedirs(p, exist_ok=True)

def main():
    if len(sys.argv) < 3:
        print("Usage: python split_dataset.py <SRC_RAW> <DST_SPLIT>")
        sys.exit(1)

    SRC = sys.argv[1]
    DST = sys.argv[2]
    SPLIT = (0.60, 0.40)   # train, test
    SEED = 42
    random.seed(SEED)

    print("Source:", SRC)
    print("Dest  :", DST)

    classes = [d for d in sorted(os.listdir(SRC))
               if os.path.isdir(os.path.join(SRC,d))]

    if not classes:
        print("[ERROR] Tidak ditemukan subfolder kelas di SRC.")
        sys.exit(1)

    for cls in classes:
        src_cls = os.path.join(SRC, cls)

        imgs = sorted([p for ext in ("*.jpg","*.jpeg","*.png","*.JPG","*.JPEG","*.PNG")
                       for p in glob.glob(os.path.join(src_cls, ext))])

        random.shuffle(imgs)
        n = len(imgs)

        if n == 0:
            print(f"[WARN] Kelas '{cls}' kosong, lewati.")
            continue

        n_train = int(SPLIT[0] * n)
        n_test  = n - n_train

        splits = {
            "train": imgs[:n_train],
            "test" : imgs[n_train:]
        }

        for split, paths in splits.items():
            dst_dir = os.path.join(DST, split, cls)
            ensure_dir(dst_dir)

            for p in paths:
                shutil.copy2(p, os.path.join(dst_dir, os.path.basename(p)))

        print(f"[OK] {cls}: {n} -> train {n_train} | test {n_test}")

    print("Done split 60/40")

if __name__ == "__main__":
    main()
# Out:
# Overwriting split_dataset.py

# %%
if DO_SPLIT:
    # !python split_dataset.py "$DATASET_RAW" "$DATASET"
else:
    print("Lewati split. Pastikan DATASET sudah berisi train/val/test.")
# Out:
# Source: /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra
# Dest  : /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random
# [OK] Agathis borneensis - Damar Putih: 100 -> train 60 | test 40
# [OK] Aquailaria beccariana - Gaharu: 100 -> train 60 | test 40
# [OK] Cotylelobum Melanoxylum - Giam Tembaga: 100 -> train 60 | test 40
# [OK] Diospyros Borneensis - Kayu Hitam: 100 -> train 60 | test 40
# [OK] Dipterocarpus Confertus - Keruing Tempudau: 100 -> train 60 | test 40
# [OK] Dipterocarpus tempehes - Keruing Asam: 100 -> train 60 | test 40
# [OK] Durio dulcis - Lahung: 100 -> train 60 | test 40
# [OK] Durio lanceolatus - Durian Anggang: 100 -> train 60 | test 40
# [OK] Durio oxleyanus - kerantungan: 100 -> train 60 | test 40
# [OK] Etlingera Balikpapanensis - Jahe Balikpapan: 100 -> train 60 | test 40
# [OK] Eusideroxylon zwageri - Ulin: 100 -> train 60 | test 40
# [OK] Hopea Mengerawan - damar cermin: 100 -> train 60 | test 40
# [OK] Hopea Rudiformis - Merawan: 100 -> train 60 | test 40
# [OK] Hopea dryobalanoides: 100 -> train 60 | test 40
# [OK] Scorodocarpus Borneensis - Kayu Bawang: 100 -> train 60 | test 40
# [OK] Shorea Agami - Meranti Putih: 100 -> train 60 | test 40
# [OK] Shorea Beccariana - Meranti Merah Muda: 100 -> train 60 | test 40
# [OK] Shorea Falciferoides : 100 -> train 60 | test 40
# [OK] Shorea Hopeifolia - Meranti Kuning: 100 -> train 60 | test 40
# [OK] Shorea Macrophylla - Meranti Merah: 100 -> train 60 | test 40
# [OK] Shorea Maxwelliana - Selangan Batu: 100 -> train 60 | test 40
# [OK] Shorea Ovalis - Meranti Kelungkung: 100 -> train 60 | test 40
# [OK] Shorea Pinanga - Tengkawang: 100 -> train 60 | test 40
# [OK] Shorea Smithiana - Merebung: 100 -> train 60 | test 40
# [OK] Shorea Stenoptera - Tengkawang Tungkul: 100 -> train 60 | test 40
# [OK] Shorea inappendiculata - Selagan: 100 -> train 60 | test 40
# [OK] Shorea pauciflora- Meranti: 100 -> train 60 | test 40
# [OK] Vatica Pauciflora - Resak Laru: 100 -> train 60 | test 40
# [OK] Vatica Sarawakensis - Resak Sarawak: 100 -> train 60 | test 40
# [OK] Vatica Umbonata - Damar Tingkis: 100 -> train 60 | test 40
# Done split 60/40

# %% [markdown]
# ## 5) Data Pipeline — RandAugment hanya TRAIN

# %%
# %%writefile data.py
import tensorflow as tf
from tensorflow import keras
from keras import layers

AUTOTUNE  = tf.data.AUTOTUNE
IMG_SIZE  = (224, 224)
LOAD_SIZE = (256, 256)
BATCH     = 32
SEED      = 42

def _build_aug():
    return keras.Sequential([
        layers.RandomCrop(IMG_SIZE[0], IMG_SIZE[1]),
        layers.RandomFlip("horizontal"),
        layers.RandAugment(value_range=(0, 255)),
    ])

def _with_map_train(ds, pipeline):
    return ds.map(
        lambda x, y: (pipeline(x, training=True), y),
        num_parallel_calls=AUTOTUNE
    )

def _with_map_test(ds):
    return ds.map(
        lambda x, y: (tf.cast(x, tf.float32), y),
        num_parallel_calls=AUTOTUNE
    )

def build_datasets(root="DATASET"):

    train_raw = keras.preprocessing.image_dataset_from_directory(
        directory=f"{root}/train",
        image_size=LOAD_SIZE,
        batch_size=BATCH,
        label_mode="categorical",
        shuffle=True,
        seed=SEED
    )

    test_raw = keras.preprocessing.image_dataset_from_directory(
        directory=f"{root}/test",
        image_size=IMG_SIZE,
        batch_size=BATCH,
        label_mode="categorical",
        shuffle=False,
        seed=SEED
    )

    class_names = train_raw.class_names
    num_classes = len(class_names)

    aug = _build_aug()

    train_ds = _with_map_train(train_raw, aug).prefetch(AUTOTUNE)
    test_ds  = _with_map_test(test_raw).prefetch(AUTOTUNE)

    total_train = sum(1 for _ in train_raw) * BATCH
    total_test  = sum(1 for _ in test_raw) * BATCH

    return train_ds, test_ds, num_classes, class_names, total_train, total_test
# Out:
# Overwriting data.py

# %% [markdown]
# ## 6) Model EfficientNetV2 (S/M/L)

# %%
# %%writefile model.py
from tensorflow import keras
from keras import layers, Model, Input
from keras.applications import EfficientNetV2S, EfficientNetV2M, EfficientNetV2L

def build_model(variant: str, num_classes: int):

    if variant.upper() == "S":
        input_shape = (224, 224, 3)
        base = EfficientNetV2S(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    elif variant.upper() == "M":
        input_shape = (480, 480, 3)
        base = EfficientNetV2M(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    elif variant.upper() == "L":
        input_shape = (480, 480, 3)
        base = EfficientNetV2L(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    else:
        raise ValueError("variant harus 'S' | 'M' | 'L'")

    base.trainable = False

    inp = Input(shape=input_shape)
    x   = base(inp, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dense(512, activation="relu")(x)
    x   = layers.Dropout(0.3)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)

    model = Model(inp, out)
    return model, base
# Out:
# Overwriting model.py

# %% [markdown]
# ## 7) Training + F1 Macro + CSV Logger & Training Time

# %%
# %%writefile train.py
import time, json
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf


def train(model, base, train_ds, epochs_phase1=30, epochs_phase2=0, out_prefix="effv2l"):

    print("\n=== PHASE 1: Training HEAD saja (full backbone frozen) ===")
    print("Backbone trainable:", base.trainable)
    print(f"Total trainable params: {sum([tf.size(w).numpy() for w in model.trainable_weights]):,}")

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-4),
        loss=keras.losses.CategoricalCrossentropy(),
        metrics=[
            "accuracy",
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall")
        ]
    )

    cb_phase1 = [
        keras.callbacks.CSVLogger(f"{out_prefix}_phase1_history.csv"),
        keras.callbacks.ModelCheckpoint(
            f"{out_prefix}_best_phase1.keras",
            monitor="accuracy",
            mode="max",
            save_best_only=True,
            verbose=1
        )
    ]

    t0 = time.time()
    hist1 = model.fit(
        train_ds,
        epochs=epochs_phase1,
        callbacks=cb_phase1,
        verbose=2
    )
    t_phase1 = time.time() - t0
    print(f"\nPhase 1 selesai dalam {t_phase1/60:.1f} menit")
    print(f"Best accuracy: {max(hist1.history['accuracy']):.4f}")

    with open(f"{out_prefix}_train_time.json", "w") as f:
        json.dump({
            "phase1_seconds": float(t_phase1),
            "total_seconds" : float(t_phase1),
            "best_accuracy" : float(max(hist1.history["accuracy"]))
        }, f, indent=2)

    return model
# Out:
# Overwriting train.py

# %% [markdown]
# ## 8) Evaluasi Test + Confusion Matrix

# %%
# %%writefile eval.py
import os
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from sklearn.metrics import (classification_report, confusion_matrix,
                             f1_score, precision_score, recall_score)

def evaluate_on_test(model, test_ds, class_names, out_prefix="effv2s"):
    """
    Evaluasi model pada test_ds.
    - y_true dikumpulkan dari dataset
    - prediksi pakai model.predict(test_ds) SATU KALI — lebih cepat & stabil
      dibanding loop per-batch yang rawan timeout/KeyboardInterrupt
    """
    # Buat folder berdasarkan out_prefix (nama variasi)
    out_dir = os.path.join("hasil", out_prefix)
    os.makedirs(out_dir, exist_ok=True)

    # Kumpulkan ground truth
    y_true = []
    for _, y in test_ds:
        y_true.extend(y.numpy().argmax(axis=1).tolist())
    y_true = np.array(y_true)

    # Predict seluruh dataset sekaligus
    print("Predicting test set...")
    y_prob = model.predict(test_ds, verbose=1)
    y_pred = y_prob.argmax(axis=1)

    # Metrics
    acc  = (y_true == y_pred).mean()
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec  = recall_score   (y_true, y_pred, average="macro", zero_division=0)
    f1   = f1_score       (y_true, y_pred, average="macro", zero_division=0)

    # Classification report
    report = classification_report(y_true, y_pred,
                                   target_names=class_names, zero_division=0)
    report_path = os.path.join(out_dir, f"{out_prefix}_test_report.txt")
    with open(report_path, "w") as f:
        f.write(report)
    print(f"Saved: {report_path}")

    # Confusion matrix — simpan CSV
    cm = confusion_matrix(y_true, y_pred)
    cm_csv_path = os.path.join(out_dir, f"{out_prefix}_confusion_matrix.csv")
    pd.DataFrame(cm, index=class_names, columns=class_names).to_csv(cm_csv_path)
    print(f"Saved: {cm_csv_path}")

    # Confusion matrix — plot
    cm_png_path = os.path.join(out_dir, f"{out_prefix}_confusion_matrix.png")
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.savefig(cm_png_path, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved: {cm_png_path}")

    print(f"TEST → Acc: {acc:.4f} | Prec(macro): {prec:.4f} | "
          f"Rec(macro): {rec:.4f} | F1(macro): {f1:.4f}")

    return {
        "accuracy":         float(acc),
        "precision_macro":  float(prec),
        "recall_macro":     float(rec),
        "f1_macro":         float(f1),
    }
# Out:
# Overwriting eval.py

# %% [markdown]
# ## 9) Uji Inference Time

# %%
# %%writefile infer_time.py
import time, csv, json
import numpy as np
import tensorflow as tf
from data import build_datasets

def measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix="effv2s"):
    all_avg_times = []

    # warm-up 1 batch
    for x, _ in test_ds.take(1):
        _ = model.predict(x, verbose=0)

    with open(f"{out_prefix}_inference_times.csv", "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["idx", "mean_time_sec", "std_time_sec"])

        grabbed = 0
        for x, _ in test_ds.unbatch().batch(1):
            if grabbed >= n_images:
                break
            times_per_image = []
            for _ in range(n_runs):
                t0 = time.time()
                model.predict(x, verbose=0)
                dt = time.time() - t0
                times_per_image.append(dt)

            mean_t = float(np.mean(times_per_image))
            std_t  = float(np.std(times_per_image))
            all_avg_times.append(mean_t)
            w.writerow([grabbed, f"{mean_t:.6f}", f"{std_t:.6f}"])
            grabbed += 1

    overall_mean = float(np.mean(all_avg_times))
    overall_std  = float(np.std(all_avg_times))

    print(f"Inference time over {grabbed} images x {n_runs} runs:")
    print(f"  Mean : {overall_mean:.6f} s")
    print(f"  Std  : {overall_std:.6f} s")

    return overall_mean, overall_std


if __name__ == "__main__":
    VARIANT = "S"  # ganti S / M / L
    OUT     = f"effv2{VARIANT.lower()}"
    ROOT_DATASET = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"
    HASIL_DIR    = f"/content/drive/MyDrive/Database_Skripsi_Dhio/hasil/{OUT}"

    model = tf.keras.models.load_model(f"{HASIL_DIR}/{OUT}_best_phase1.keras")
    print("Model loaded:", model.name)

    _, test_ds, _, _, _, _ = build_datasets(root=ROOT_DATASET)

    mean_t, std_t = measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix=f"{HASIL_DIR}/{OUT}")

    with open(f"{HASIL_DIR}/{OUT}_inference_avg.json", "w") as f:
        json.dump({"mean_inference_time_sec": mean_t, "std_inference_time_sec": std_t}, f, indent=2)

    print(f"Selesai. Hasil disimpan di: {HASIL_DIR}")
# Out:
# Overwriting infer_time.py

# %%
# !python infer_time.py
# Out:
# 2026-04-13 12:26:10.925116: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776083170.946066   22931 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776083170.952782   22931 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776083170.969174   22931 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776083170.969198   22931 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776083170.969201   22931 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776083170.969203   22931 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-13 12:26:16.926478: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1776083176.927969   22931 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model loaded: functional_1
# Found 1800 files belonging to 30 classes.
# Found 1200 files belonging to 30 classes.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776083192.644722   23019 service.cc:152] XLA service 0x7e65c801c150 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776083192.644783   23019 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776083194.333928   23019 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-13 12:26:38.408976: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:38.549083: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:39.433044: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:39.577698: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:41.062962: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:41.215604: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1776083203.939218   23019 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-13 12:26:53.488945: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:53.621330: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:54.474992: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:54.608895: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:56.090917: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:26:56.234779: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Inference time over 100 images x 10 runs:
#   Mean : 0.098986 s
#   Std  : 0.151013 s
# Selesai. Hasil disimpan di: /content/drive/MyDrive/Database_Skripsi_Dhio/hasil/effv2s

# %% [markdown]
# ## 10) Main (Skenario eksperimen S/M/L)

# %%
# %%writefile main.py
import json, os
import tensorflow as tf
from data import build_datasets
from model import build_model
from train import train
from eval import evaluate_on_test
from infer_time import measure_inference_time

# === PARAMETER SKENARIO ===

VARIANT       = "S"
EPOCHS_PHASE1 = 50
EPOCHS_PHASE2 = 0
OUT           = f"effv2{VARIANT.lower()}"
ROOT_DATASET  = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"

tf.random.set_seed(42)

# === Data ===
train_ds, test_ds, num_classes, class_names, total_train, total_test = build_datasets(root=ROOT_DATASET)
class_names = tuple(class_names)
print(f"Classes ({num_classes}):", class_names)
print(f"Total train samples : ~{total_train}")
print(f"Total test samples  : ~{total_test}")
print(f"Augmentasi          : Online (RandAugment) — jumlah data tidak berubah")

# === Model ===
model, base = build_model(VARIANT, num_classes)
model.summary()

# === Train (Phase 1 saja) ===
model = train(
    model, base, train_ds,
    epochs_phase1=EPOCHS_PHASE1,
    epochs_phase2=EPOCHS_PHASE2,
    out_prefix=OUT
)

# === Evaluate (TEST) ===
metrics_test = evaluate_on_test(model, test_ds, class_names, out_prefix=OUT)
with open(f"{OUT}_test_metrics.json", "w") as f:
        json.dump(metrics_test, f, indent=2)

# === Inference time ===
avg_inf = measure_inference_time(model, test_ds, n_images=100, out_prefix=OUT)
with open(f"{OUT}_inference_avg.json", "w") as f:
    json.dump({"avg_inference_time_sec": avg_inf}, f, indent=2)

print("\nSelesai. File output tersimpan dengan prefix:", OUT)
# Out:
# Overwriting main.py

# %% [markdown]
# ## 11) Jalankan skenario (ubah VARIANT di `main.py` bila perlu)

# %%
# !python main.py
# Out:
# 2026-04-13 11:41:25.493579: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776080485.515609    7835 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776080485.522745    7835 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776080485.541967    7835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080485.541994    7835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080485.541996    7835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776080485.541999    7835 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Found 1800 files belonging to 30 classes.
# 2026-04-13 11:41:31.368950: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1776080491.370381    7835 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 1200 files belonging to 30 classes.
# Classes (30): ('Agathis borneensis - Damar Putih', 'Aquailaria beccariana - Gaharu', 'Cotylelobum Melanoxylum - Giam Tembaga', 'Diospyros Borneensis - Kayu Hitam', 'Dipterocarpus Confertus - Keruing Tempudau', 'Dipterocarpus tempehes - Keruing Asam', 'Durio dulcis - Lahung', 'Durio lanceolatus - Durian Anggang', 'Durio oxleyanus - kerantungan', 'Etlingera Balikpapanensis - Jahe Balikpapan', 'Eusideroxylon zwageri - Ulin', 'Hopea Mengerawan - damar cermin', 'Hopea Rudiformis - Merawan', 'Hopea dryobalanoides', 'Scorodocarpus Borneensis - Kayu Bawang', 'Shorea Agami - Meranti Putih', 'Shorea Beccariana - Meranti Merah Muda', 'Shorea Falciferoides ', 'Shorea Hopeifolia - Meranti Kuning', 'Shorea Macrophylla - Meranti Merah', 'Shorea Maxwelliana - Selangan Batu', 'Shorea Ovalis - Meranti Kelungkung', 'Shorea Pinanga - Tengkawang', 'Shorea Smithiana - Merebung', 'Shorea Stenoptera - Tengkawang Tungkul', 'Shorea inappendiculata - Selagan', 'Shorea pauciflora- Meranti', 'Vatica Pauciflora - Resak Laru', 'Vatica Sarawakensis - Resak Sarawak', 'Vatica Umbonata - Damar Tingkis')
# Total train samples : ~1824
# Total test samples  : ~1216
# Augmentasi          : Online (RandAugment) — jumlah data tidak berubah
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-s (Functional)   │ (None, 7, 7, 1280)     │    20,331,360 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │        15,390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,002,622 (80.12 MB)
#  Trainable params: 671,262 (2.56 MB)
#  Non-trainable params: 20,331,360 (77.56 MB)
#
# === PHASE 1: Training HEAD saja (full backbone frozen) ===
# Backbone trainable: False
# Total trainable params: 671,262
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776080526.311216    7918 service.cc:152] XLA service 0x79bc40003830 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776080526.311276    7918 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1776080530.915651    7918 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-13 11:42:20.062706: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:42:20.202175: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:42:21.077467: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:42:21.219843: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:42:22.676883: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:42:22.827621: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1776080556.681088    7918 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-13 11:43:16.689575: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:43:16.823101: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:43:17.655254: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:43:17.791332: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:43:19.252493: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 11:43:19.403539: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#
# Epoch 1: accuracy improved from None to 0.08722, saving model to effv2s_best_phase1.keras
#
# Epoch 1: finished saving model to effv2s_best_phase1.keras
# 57/57 - 121s - 2s/step - accuracy: 0.0872 - loss: 3.2630 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/50
#
# Epoch 2: accuracy improved from 0.08722 to 0.30944, saving model to effv2s_best_phase1.keras
#
# Epoch 2: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 674ms/step - accuracy: 0.3094 - loss: 2.8286 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/50
#
# Epoch 3: accuracy improved from 0.30944 to 0.44222, saving model to effv2s_best_phase1.keras
#
# Epoch 3: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 685ms/step - accuracy: 0.4422 - loss: 2.3876 - precision: 1.0000 - recall: 0.0022
# Epoch 4/50
#
# Epoch 4: accuracy improved from 0.44222 to 0.51111, saving model to effv2s_best_phase1.keras
#
# Epoch 4: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 687ms/step - accuracy: 0.5111 - loss: 2.1219 - precision: 0.9600 - recall: 0.0267
# Epoch 5/50
#
# Epoch 5: accuracy improved from 0.51111 to 0.56722, saving model to effv2s_best_phase1.keras
#
# Epoch 5: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 680ms/step - accuracy: 0.5672 - loss: 1.8557 - precision: 0.9509 - recall: 0.0861
# Epoch 6/50
#
# Epoch 6: accuracy improved from 0.56722 to 0.60778, saving model to effv2s_best_phase1.keras
#
# Epoch 6: finished saving model to effv2s_best_phase1.keras
# 57/57 - 40s - 699ms/step - accuracy: 0.6078 - loss: 1.6278 - precision: 0.9711 - recall: 0.1678
# Epoch 7/50
#
# Epoch 7: accuracy improved from 0.60778 to 0.61611, saving model to effv2s_best_phase1.keras
#
# Epoch 7: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 685ms/step - accuracy: 0.6161 - loss: 1.5575 - precision: 0.9537 - recall: 0.2289
# Epoch 8/50
#
# Epoch 8: accuracy improved from 0.61611 to 0.62667, saving model to effv2s_best_phase1.keras
#
# Epoch 8: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 673ms/step - accuracy: 0.6267 - loss: 1.4396 - precision: 0.9455 - recall: 0.2794
# Epoch 9/50
#
# Epoch 9: accuracy improved from 0.62667 to 0.64111, saving model to effv2s_best_phase1.keras
#
# Epoch 9: finished saving model to effv2s_best_phase1.keras
# 57/57 - 40s - 693ms/step - accuracy: 0.6411 - loss: 1.4152 - precision: 0.9205 - recall: 0.2894
# Epoch 10/50
#
# Epoch 10: accuracy improved from 0.64111 to 0.64778, saving model to effv2s_best_phase1.keras
#
# Epoch 10: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 672ms/step - accuracy: 0.6478 - loss: 1.3413 - precision: 0.9287 - recall: 0.3400
# Epoch 11/50
#
# Epoch 11: accuracy improved from 0.64778 to 0.66833, saving model to effv2s_best_phase1.keras
#
# Epoch 11: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 663ms/step - accuracy: 0.6683 - loss: 1.2676 - precision: 0.9335 - recall: 0.3667
# Epoch 12/50
#
# Epoch 12: accuracy improved from 0.66833 to 0.71333, saving model to effv2s_best_phase1.keras
#
# Epoch 12: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 689ms/step - accuracy: 0.7133 - loss: 1.1276 - precision: 0.9394 - recall: 0.4222
# Epoch 13/50
#
# Epoch 13: accuracy did not improve from 0.71333
# 57/57 - 37s - 646ms/step - accuracy: 0.7011 - loss: 1.1487 - precision: 0.9365 - recall: 0.4344
# Epoch 14/50
#
# Epoch 14: accuracy improved from 0.71333 to 0.71778, saving model to effv2s_best_phase1.keras
#
# Epoch 14: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 671ms/step - accuracy: 0.7178 - loss: 1.0865 - precision: 0.9219 - recall: 0.4528
# Epoch 15/50
#
# Epoch 15: accuracy improved from 0.71778 to 0.74778, saving model to effv2s_best_phase1.keras
#
# Epoch 15: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 680ms/step - accuracy: 0.7478 - loss: 0.9741 - precision: 0.9363 - recall: 0.5061
# Epoch 16/50
#
# Epoch 16: accuracy did not improve from 0.74778
# 57/57 - 37s - 645ms/step - accuracy: 0.7217 - loss: 1.0204 - precision: 0.9263 - recall: 0.5100
# Epoch 17/50
#
# Epoch 17: accuracy improved from 0.74778 to 0.76222, saving model to effv2s_best_phase1.keras
#
# Epoch 17: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 684ms/step - accuracy: 0.7622 - loss: 0.9163 - precision: 0.9296 - recall: 0.5428
# Epoch 18/50
#
# Epoch 18: accuracy did not improve from 0.76222
# 57/57 - 37s - 654ms/step - accuracy: 0.7483 - loss: 0.9421 - precision: 0.9257 - recall: 0.5333
# Epoch 19/50
#
# Epoch 19: accuracy did not improve from 0.76222
# 57/57 - 37s - 650ms/step - accuracy: 0.7511 - loss: 0.9219 - precision: 0.9171 - recall: 0.5528
# Epoch 20/50
#
# Epoch 20: accuracy improved from 0.76222 to 0.76444, saving model to effv2s_best_phase1.keras
#
# Epoch 20: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 673ms/step - accuracy: 0.7644 - loss: 0.8826 - precision: 0.9257 - recall: 0.5678
# Epoch 21/50
#
# Epoch 21: accuracy did not improve from 0.76444
# 57/57 - 37s - 653ms/step - accuracy: 0.7606 - loss: 0.8676 - precision: 0.9234 - recall: 0.5961
# Epoch 22/50
#
# Epoch 22: accuracy improved from 0.76444 to 0.76611, saving model to effv2s_best_phase1.keras
#
# Epoch 22: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 671ms/step - accuracy: 0.7661 - loss: 0.8135 - precision: 0.9231 - recall: 0.6072
# Epoch 23/50
#
# Epoch 23: accuracy improved from 0.76611 to 0.79000, saving model to effv2s_best_phase1.keras
#
# Epoch 23: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 663ms/step - accuracy: 0.7900 - loss: 0.8002 - precision: 0.9303 - recall: 0.6233
# Epoch 24/50
#
# Epoch 24: accuracy improved from 0.79000 to 0.80444, saving model to effv2s_best_phase1.keras
#
# Epoch 24: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 687ms/step - accuracy: 0.8044 - loss: 0.7344 - precision: 0.9347 - recall: 0.6517
# Epoch 25/50
#
# Epoch 25: accuracy did not improve from 0.80444
# 57/57 - 37s - 644ms/step - accuracy: 0.7828 - loss: 0.7804 - precision: 0.9360 - recall: 0.6333
# Epoch 26/50
#
# Epoch 26: accuracy improved from 0.80444 to 0.81667, saving model to effv2s_best_phase1.keras
#
# Epoch 26: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 680ms/step - accuracy: 0.8167 - loss: 0.7086 - precision: 0.9218 - recall: 0.6617
# Epoch 27/50
#
# Epoch 27: accuracy did not improve from 0.81667
# 57/57 - 37s - 655ms/step - accuracy: 0.8056 - loss: 0.7515 - precision: 0.9322 - recall: 0.6417
# Epoch 28/50
#
# Epoch 28: accuracy did not improve from 0.81667
# 57/57 - 37s - 644ms/step - accuracy: 0.8133 - loss: 0.6798 - precision: 0.9404 - recall: 0.6928
# Epoch 29/50
#
# Epoch 29: accuracy did not improve from 0.81667
# 57/57 - 36s - 640ms/step - accuracy: 0.7822 - loss: 0.7822 - precision: 0.9156 - recall: 0.6511
# Epoch 30/50
#
# Epoch 30: accuracy did not improve from 0.81667
# 57/57 - 37s - 647ms/step - accuracy: 0.8128 - loss: 0.6900 - precision: 0.9226 - recall: 0.6822
# Epoch 31/50
#
# Epoch 31: accuracy did not improve from 0.81667
# 57/57 - 37s - 642ms/step - accuracy: 0.8144 - loss: 0.6769 - precision: 0.9318 - recall: 0.6978
# Epoch 32/50
#
# Epoch 32: accuracy did not improve from 0.81667
# 57/57 - 37s - 646ms/step - accuracy: 0.8011 - loss: 0.7221 - precision: 0.9291 - recall: 0.6622
# Epoch 33/50
#
# Epoch 33: accuracy did not improve from 0.81667
# 57/57 - 36s - 637ms/step - accuracy: 0.8156 - loss: 0.6538 - precision: 0.9300 - recall: 0.7017
# Epoch 34/50
#
# Epoch 34: accuracy did not improve from 0.81667
# 57/57 - 37s - 643ms/step - accuracy: 0.8028 - loss: 0.7068 - precision: 0.9237 - recall: 0.6728
# Epoch 35/50
#
# Epoch 35: accuracy improved from 0.81667 to 0.81833, saving model to effv2s_best_phase1.keras
#
# Epoch 35: finished saving model to effv2s_best_phase1.keras
# 57/57 - 37s - 655ms/step - accuracy: 0.8183 - loss: 0.6728 - precision: 0.9354 - recall: 0.6994
# Epoch 36/50
#
# Epoch 36: accuracy improved from 0.81833 to 0.83944, saving model to effv2s_best_phase1.keras
#
# Epoch 36: finished saving model to effv2s_best_phase1.keras
# 57/57 - 39s - 687ms/step - accuracy: 0.8394 - loss: 0.6378 - precision: 0.9326 - recall: 0.7150
# Epoch 37/50
#
# Epoch 37: accuracy did not improve from 0.83944
# 57/57 - 37s - 644ms/step - accuracy: 0.8172 - loss: 0.6576 - precision: 0.9405 - recall: 0.6933
# Epoch 38/50
#
# Epoch 38: accuracy did not improve from 0.83944
# 57/57 - 37s - 643ms/step - accuracy: 0.8189 - loss: 0.6571 - precision: 0.9231 - recall: 0.7072
# Epoch 39/50
#
# Epoch 39: accuracy did not improve from 0.83944
# 57/57 - 36s - 638ms/step - accuracy: 0.8322 - loss: 0.5882 - precision: 0.9273 - recall: 0.7367
# Epoch 40/50
#
# Epoch 40: accuracy improved from 0.83944 to 0.85333, saving model to effv2s_best_phase1.keras
#
# Epoch 40: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 673ms/step - accuracy: 0.8533 - loss: 0.5554 - precision: 0.9484 - recall: 0.7561
# Epoch 41/50
#
# Epoch 41: accuracy did not improve from 0.85333
# 57/57 - 37s - 644ms/step - accuracy: 0.8178 - loss: 0.6308 - precision: 0.9117 - recall: 0.7172
# Epoch 42/50
#
# Epoch 42: accuracy did not improve from 0.85333
# 57/57 - 36s - 635ms/step - accuracy: 0.8367 - loss: 0.5804 - precision: 0.9274 - recall: 0.7378
# Epoch 43/50
#
# Epoch 43: accuracy did not improve from 0.85333
# 57/57 - 37s - 647ms/step - accuracy: 0.8328 - loss: 0.6053 - precision: 0.9278 - recall: 0.7422
# Epoch 44/50
#
# Epoch 44: accuracy did not improve from 0.85333
# 57/57 - 37s - 648ms/step - accuracy: 0.8411 - loss: 0.5887 - precision: 0.9304 - recall: 0.7356
# Epoch 45/50
#
# Epoch 45: accuracy did not improve from 0.85333
# 57/57 - 36s - 634ms/step - accuracy: 0.8422 - loss: 0.5994 - precision: 0.9275 - recall: 0.7389
# Epoch 46/50
#
# Epoch 46: accuracy did not improve from 0.85333
# 57/57 - 37s - 646ms/step - accuracy: 0.8500 - loss: 0.5232 - precision: 0.9289 - recall: 0.7622
# Epoch 47/50
#
# Epoch 47: accuracy improved from 0.85333 to 0.85944, saving model to effv2s_best_phase1.keras
#
# Epoch 47: finished saving model to effv2s_best_phase1.keras
# 57/57 - 38s - 671ms/step - accuracy: 0.8594 - loss: 0.5188 - precision: 0.9361 - recall: 0.7728
# Epoch 48/50
#
# Epoch 48: accuracy improved from 0.85944 to 0.86944, saving model to effv2s_best_phase1.keras
#
# Epoch 48: finished saving model to effv2s_best_phase1.keras
# 57/57 - 40s - 707ms/step - accuracy: 0.8694 - loss: 0.4969 - precision: 0.9513 - recall: 0.7922
# Epoch 49/50
#
# Epoch 49: accuracy did not improve from 0.86944
# 57/57 - 37s - 654ms/step - accuracy: 0.8483 - loss: 0.5623 - precision: 0.9319 - recall: 0.7606
# Epoch 50/50
#
# Epoch 50: accuracy did not improve from 0.86944
# 57/57 - 36s - 640ms/step - accuracy: 0.8494 - loss: 0.5378 - precision: 0.9291 - recall: 0.7639
#
# Phase 1 selesai dalam 32.8 menit
# Best accuracy: 0.8694
# Predicting test set...
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step2026-04-13 12:14:54.933942: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:14:55.069766: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:14:55.923302: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:14:56.061682: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:14:57.547857: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:14:57.700123: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 28s 491ms/step
# Saved: hasil/effv2s/effv2s_test_report.txt
# Saved: hasil/effv2s/effv2s_confusion_matrix.csv
# Saved: hasil/effv2s/effv2s_confusion_matrix.png
# TEST → Acc: 0.9542 | Prec(macro): 0.9566 | Rec(macro): 0.9542 | F1(macro): 0.9541
# 2026-04-13 12:15:20.294328: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:15:20.426828: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:15:21.243821: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:15:21.377849: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:15:22.879368: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-13 12:15:23.024033: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Avg inference time over 100 images: 0.233479s
#
# Selesai. File output tersimpan dengan prefix: effv2s

# %%
# !ls
# Out:
# data.py  Dataset_Citra	 eval.py	main.py   __pycache__	    train.py
# Dataset  Dataset_Mentah  infer_time.py	model.py  split_dataset.py
