# %% [markdown]
# # Skripsi Dhio — Klasifikasi Flora Endemik Kalimantan
#
# **Perubahan dari V9 :**
# - menghilangkan early stopping
# - menghilangkan learning rate schedule dan weight decay
#
# Struktur Drive:
# ```
# MyDrive/
# └─ Database Skripsi Dhio/
#    ├─ Dataset Mentah/
#    │  ├─ Spesies_A/  (100+ citra mentah)
#    │  ├─ Spesies_B/
#    │  └─ ...
#    └─ Dataset/
# ```

# %% [markdown]
# ## 0) Runtime & GPU

# %%
# Pastikan runtime GPU aktif (Runtime → Change runtime type → GPU)
import tensorflow as tf
print("TF version:", tf.__version__)
print("GPU:", tf.config.list_physical_devices('GPU'))
# Out:
# TF version: 2.19.0
# GPU: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## 1) Install KerasCV (untuk RandAugment)

# %%
# !pip install keras-cv
# Out:
# Collecting keras-cv
#   Downloading keras_cv-0.9.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-cv) (26.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.12/dist-packages (from keras-cv) (2025.11.3)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.12/dist-packages (from keras-cv) (4.9.9)
# Collecting keras-core (from keras-cv)
#   Downloading keras_core-0.1.7-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (from keras-cv) (1.0.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.14 in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (0.1.18)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub->keras-cv) (4.67.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (3.16.0)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.12/dist-packages (from keras-core->keras-cv) (0.1.10)
# Requirement already satisfied: array_record>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.8.3)
# Requirement already satisfied: etils>=1.9.1 in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (1.14.0)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (4.3.1)
# Requirement already satisfied: promise in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.29.6)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (18.1.0)
# Requirement already satisfied: simple_parsing in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.1.8)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (1.17.3)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (3.3.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from tensorflow-datasets->keras-cv) (2.1.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (0.8.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (2025.3.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (4.15.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.9.1; python_version >= "3.11"->tensorflow-datasets->keras-cv) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->kagglehub->keras-cv) (2026.2.25)
# Requirement already satisfied: attrs>=18.2.0 in /usr/local/lib/python3.12/dist-packages (from dm-tree->keras-core->keras-cv) (26.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from promise->tensorflow-datasets->keras-cv) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras-core->keras-cv) (2.20.0)
# Requirement already satisfied: docstring-parser~=0.15 in /usr/local/lib/python3.12/dist-packages (from simple_parsing->tensorflow-datasets->keras-cv) (0.17.0)
# Requirement already satisfied: googleapis-common-protos<2,>=1.56.4 in /usr/local/lib/python3.12/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras-cv) (1.74.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras-cv) (0.1.2)
# Downloading keras_cv-0.9.0-py3-none-any.whl (650 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 650.7/650.7 kB 40.1 MB/s eta 0:00:00
# Downloading keras_core-0.1.7-py3-none-any.whl (950 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 950.8/950.8 kB 30.9 MB/s eta 0:00:00
# Installing collected packages: keras-core, keras-cv
# Successfully installed keras-core-0.1.7 keras-cv-0.9.0

# %% [markdown]
# ## 2) Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 3) Konfigurasi path (Sesuai Drive Dhio)

# %%
# === KONFIGURASI ===
PROJECT_DIR = "/content/drive/MyDrive/Database_Skripsi_Dhio"
DATASET_RAW = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra"
DATASET     = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"

DO_SPLIT = True

import os
os.makedirs(PROJECT_DIR, exist_ok=True)
# %cd $PROJECT_DIR
print("Project dir:", PROJECT_DIR)
print("Raw dataset:", DATASET_RAW)
print("Split out   :", DATASET)
# Out:
# /content/drive/MyDrive/Database_Skripsi_Dhio
# Project dir: /content/drive/MyDrive/Database_Skripsi_Dhio
# Raw dataset: /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra
# Split out   : /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random

# %% [markdown]
# ## 4) Script Split 60/40 secara random

# %%
# %%writefile split_dataset.py
import os, shutil, random, glob, sys

def ensure_dir(p):
    os.makedirs(p, exist_ok=True)

def main():
    if len(sys.argv) < 3:
        print("Usage: python split_dataset.py <SRC_RAW> <DST_SPLIT>")
        sys.exit(1)

    SRC = sys.argv[1]
    DST = sys.argv[2]
    SPLIT = (0.60, 0.40)   # train, test
    SEED = 42
    random.seed(SEED)

    print("Source:", SRC)
    print("Dest  :", DST)

    classes = [d for d in sorted(os.listdir(SRC))
               if os.path.isdir(os.path.join(SRC,d))]

    if not classes:
        print("[ERROR] Tidak ditemukan subfolder kelas di SRC.")
        sys.exit(1)

    for cls in classes:
        src_cls = os.path.join(SRC, cls)

        imgs = sorted([p for ext in ("*.jpg","*.jpeg","*.png","*.JPG","*.JPEG","*.PNG")
                       for p in glob.glob(os.path.join(src_cls, ext))])

        random.shuffle(imgs)
        n = len(imgs)

        if n == 0:
            print(f"[WARN] Kelas '{cls}' kosong, lewati.")
            continue

        n_train = int(SPLIT[0] * n)
        n_test  = n - n_train

        splits = {
            "train": imgs[:n_train],
            "test" : imgs[n_train:]
        }

        for split, paths in splits.items():
            dst_dir = os.path.join(DST, split, cls)
            ensure_dir(dst_dir)

            for p in paths:
                shutil.copy2(p, os.path.join(dst_dir, os.path.basename(p)))

        print(f"[OK] {cls}: {n} -> train {n_train} | test {n_test}")

    print("Done split 60/40")

if __name__ == "__main__":
    main()
# Out:
# Overwriting split_dataset.py

# %%
if DO_SPLIT:
    # !python split_dataset.py "$DATASET_RAW" "$DATASET"
else:
    print("Lewati split. Pastikan DATASET sudah berisi train/val/test.")
# Out:
# Source: /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset_Citra
# Dest  : /content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random
# [OK] Agathis borneensis - Damar Putih: 100 -> train 60 | test 40
# [OK] Aquailaria beccariana - Gaharu: 100 -> train 60 | test 40
# [OK] Cotylelobum Melanoxylum - Giam Tembaga: 100 -> train 60 | test 40
# [OK] Diospyros Borneensis - Kayu Hitam: 100 -> train 60 | test 40
# [OK] Dipterocarpus Confertus - Keruing Tempudau: 100 -> train 60 | test 40
# [OK] Dipterocarpus tempehes - Keruing Asam: 100 -> train 60 | test 40
# [OK] Durio dulcis - Lahung: 100 -> train 60 | test 40
# [OK] Durio lanceolatus - Durian Anggang: 100 -> train 60 | test 40
# [OK] Durio oxleyanus - kerantungan: 100 -> train 60 | test 40
# [OK] Etlingera Balikpapanensis - Jahe Balikpapan: 100 -> train 60 | test 40
# [OK] Eusideroxylon zwageri - Ulin: 100 -> train 60 | test 40
# [OK] Hopea Mengerawan - damar cermin: 100 -> train 60 | test 40
# [OK] Hopea Rudiformis - Merawan: 100 -> train 60 | test 40
# [OK] Hopea dryobalanoides: 100 -> train 60 | test 40
# [OK] Scorodocarpus Borneensis - Kayu Bawang: 100 -> train 60 | test 40
# [OK] Shorea Agami - Meranti Putih: 100 -> train 60 | test 40
# [OK] Shorea Beccariana - Meranti Merah Muda: 100 -> train 60 | test 40
# [OK] Shorea Falciferoides : 100 -> train 60 | test 40
# [OK] Shorea Hopeifolia - Meranti Kuning: 100 -> train 60 | test 40
# [OK] Shorea Macrophylla - Meranti Merah: 100 -> train 60 | test 40
# [OK] Shorea Maxwelliana - Selangan Batu: 100 -> train 60 | test 40
# [OK] Shorea Ovalis - Meranti Kelungkung: 100 -> train 60 | test 40
# [OK] Shorea Pinanga - Tengkawang: 100 -> train 60 | test 40
# [OK] Shorea Smithiana - Merebung: 100 -> train 60 | test 40
# [OK] Shorea Stenoptera - Tengkawang Tungkul: 100 -> train 60 | test 40
# [OK] Shorea inappendiculata - Selagan: 100 -> train 60 | test 40
# [OK] Shorea pauciflora- Meranti: 100 -> train 60 | test 40
# [OK] Vatica Pauciflora - Resak Laru: 100 -> train 60 | test 40
# [OK] Vatica Sarawakensis - Resak Sarawak: 100 -> train 60 | test 40
# [OK] Vatica Umbonata - Damar Tingkis: 100 -> train 60 | test 40
# Done split 60/40

# %% [markdown]
# ## 5) Data Pipeline — RandAugment hanya TRAIN

# %%
# %%writefile data.py
import tensorflow as tf
from tensorflow import keras
from keras import layers

AUTOTUNE  = tf.data.AUTOTUNE
IMG_SIZE  = (480, 480)
LOAD_SIZE = (512, 512)
BATCH     = 32
SEED      = 42

def _build_aug():
    return keras.Sequential([
        layers.RandomCrop(IMG_SIZE[0], IMG_SIZE[1]),
        layers.RandomFlip("horizontal"),
        layers.RandAugment(value_range=(0, 255)),
    ])

def _with_map_train(ds, pipeline):
    return ds.map(
        lambda x, y: (pipeline(x, training=True), y),
        num_parallel_calls=AUTOTUNE
    )

def _with_map_test(ds):
    return ds.map(
        lambda x, y: (tf.cast(x, tf.float32), y),
        num_parallel_calls=AUTOTUNE
    )

def build_datasets(root="DATASET"):

    train_raw = keras.preprocessing.image_dataset_from_directory(
        directory=f"{root}/train",
        image_size=LOAD_SIZE,
        batch_size=BATCH,
        label_mode="categorical",
        shuffle=True,
        seed=SEED
    )

    test_raw = keras.preprocessing.image_dataset_from_directory(
        directory=f"{root}/test",
        image_size=IMG_SIZE,
        batch_size=BATCH,
        label_mode="categorical",
        shuffle=False,
        seed=SEED
    )

    class_names = train_raw.class_names
    num_classes = len(class_names)

    aug = _build_aug()

    train_ds = _with_map_train(train_raw, aug).prefetch(AUTOTUNE)
    test_ds  = _with_map_test(test_raw).prefetch(AUTOTUNE)

    total_train = sum(1 for _ in train_raw) * BATCH
    total_test  = sum(1 for _ in test_raw) * BATCH

    return train_ds, test_ds, num_classes, class_names, total_train, total_test
# Out:
# Overwriting data.py

# %% [markdown]
# ## 6) Model EfficientNetV2 (S/M/L)

# %%
# %%writefile model.py
from tensorflow import keras
from keras import layers, Model, Input
from keras.applications import EfficientNetV2S, EfficientNetV2M, EfficientNetV2L

def build_model(variant: str, num_classes: int):

    if variant.upper() == "S":
        input_shape = (224, 224, 3)
        base = EfficientNetV2S(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    elif variant.upper() == "M":
        input_shape = (480, 480, 3)
        base = EfficientNetV2M(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    elif variant.upper() == "L":
        input_shape = (480, 480, 3)
        base = EfficientNetV2L(
            include_top=False,
            weights="imagenet",
            input_shape=input_shape,
            include_preprocessing=True
        )
    else:
        raise ValueError("variant harus 'S' | 'M' | 'L'")

    base.trainable = False

    inp = Input(shape=input_shape)
    x   = base(inp, training=False)
    x   = layers.GlobalAveragePooling2D()(x)
    x   = layers.Dense(512, activation="relu")(x)
    x   = layers.Dropout(0.3)(x)
    out = layers.Dense(num_classes, activation="softmax")(x)

    model = Model(inp, out)
    return model, base
# Out:
# Overwriting model.py

# %% [markdown]
# ## 7) Training + F1 Macro + CSV Logger & Training Time

# %%
# %%writefile train.py
import time, json
import pandas as pd
import numpy as np
from tensorflow import keras
import tensorflow as tf


def train(model, base, train_ds, epochs_phase1=30, epochs_phase2=0, out_prefix="effv2l"):

    print("\n=== PHASE 1: Training HEAD saja (full backbone frozen) ===")
    print("Backbone trainable:", base.trainable)
    print(f"Total trainable params: {sum([tf.size(w).numpy() for w in model.trainable_weights]):,}")

    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-4),
        loss=keras.losses.CategoricalCrossentropy(),
        metrics=[
            "accuracy",
            keras.metrics.Precision(name="precision"),
            keras.metrics.Recall(name="recall")
        ]
    )

    cb_phase1 = [
        keras.callbacks.CSVLogger(f"{out_prefix}_phase1_history.csv"),
        keras.callbacks.ModelCheckpoint(
            f"{out_prefix}_best_phase1.keras",
            monitor="accuracy",
            mode="max",
            save_best_only=True,
            verbose=1
        )
    ]

    t0 = time.time()
    hist1 = model.fit(
        train_ds,
        epochs=epochs_phase1,
        callbacks=cb_phase1,
        verbose=2
    )
    t_phase1 = time.time() - t0
    print(f"\nPhase 1 selesai dalam {t_phase1/60:.1f} menit")
    print(f"Best accuracy: {max(hist1.history['accuracy']):.4f}")

    with open(f"{out_prefix}_train_time.json", "w") as f:
        json.dump({
            "phase1_seconds": float(t_phase1),
            "total_seconds" : float(t_phase1),
            "best_accuracy" : float(max(hist1.history["accuracy"]))
        }, f, indent=2)

    return model
# Out:
# Overwriting train.py

# %% [markdown]
# ## 8) Evaluasi Test + Confusion Matrix

# %%
# %%writefile eval.py
import os
import numpy as np, pandas as pd, matplotlib.pyplot as plt
from sklearn.metrics import (classification_report, confusion_matrix,
                             f1_score, precision_score, recall_score)

def evaluate_on_test(model, test_ds, class_names, out_prefix="effv2s"):
    """
    Evaluasi model pada test_ds.
    - y_true dikumpulkan dari dataset
    - prediksi pakai model.predict(test_ds) SATU KALI — lebih cepat & stabil
      dibanding loop per-batch yang rawan timeout/KeyboardInterrupt
    """
    # Buat folder berdasarkan out_prefix (nama variasi)
    out_dir = os.path.join("hasil", out_prefix)
    os.makedirs(out_dir, exist_ok=True)

    # Kumpulkan ground truth
    y_true = []
    for _, y in test_ds:
        y_true.extend(y.numpy().argmax(axis=1).tolist())
    y_true = np.array(y_true)

    # Predict seluruh dataset sekaligus
    print("Predicting test set...")
    y_prob = model.predict(test_ds, verbose=1)
    y_pred = y_prob.argmax(axis=1)

    # Metrics
    acc  = (y_true == y_pred).mean()
    prec = precision_score(y_true, y_pred, average="macro", zero_division=0)
    rec  = recall_score   (y_true, y_pred, average="macro", zero_division=0)
    f1   = f1_score       (y_true, y_pred, average="macro", zero_division=0)

    # Classification report
    report = classification_report(y_true, y_pred,
                                   target_names=class_names, zero_division=0)
    report_path = os.path.join(out_dir, f"{out_prefix}_test_report.txt")
    with open(report_path, "w") as f:
        f.write(report)
    print(f"Saved: {report_path}")

    # Confusion matrix — simpan CSV
    cm = confusion_matrix(y_true, y_pred)
    cm_csv_path = os.path.join(out_dir, f"{out_prefix}_confusion_matrix.csv")
    pd.DataFrame(cm, index=class_names, columns=class_names).to_csv(cm_csv_path)
    print(f"Saved: {cm_csv_path}")

    # Confusion matrix — plot
    cm_png_path = os.path.join(out_dir, f"{out_prefix}_confusion_matrix.png")
    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation="nearest")
    plt.title("Confusion Matrix")
    plt.colorbar()
    tick_marks = np.arange(len(class_names))
    plt.xticks(tick_marks, class_names, rotation=45, ha="right")
    plt.yticks(tick_marks, class_names)
    plt.tight_layout()
    plt.ylabel("True label")
    plt.xlabel("Predicted label")
    plt.savefig(cm_png_path, dpi=200, bbox_inches="tight")
    plt.close()
    print(f"Saved: {cm_png_path}")

    print(f"TEST → Acc: {acc:.4f} | Prec(macro): {prec:.4f} | "
          f"Rec(macro): {rec:.4f} | F1(macro): {f1:.4f}")

    return {
        "accuracy":         float(acc),
        "precision_macro":  float(prec),
        "recall_macro":     float(rec),
        "f1_macro":         float(f1),
    }
# Out:
# Overwriting eval.py

# %% [markdown]
# ## 9) Uji Inference Time

# %%
# %%writefile infer_time.py
import time, csv, json
import numpy as np
import tensorflow as tf
from data import build_datasets

def measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix="effv2s"):
    all_avg_times = []

    # warm-up 1 batch
    for x, _ in test_ds.take(1):
        _ = model.predict(x, verbose=0)

    with open(f"{out_prefix}_inference_times.csv", "w", newline="") as f:
        w = csv.writer(f)
        w.writerow(["idx", "mean_time_sec", "std_time_sec"])

        grabbed = 0
        for x, _ in test_ds.unbatch().batch(1):
            if grabbed >= n_images:
                break
            times_per_image = []
            for _ in range(n_runs):
                t0 = time.time()
                model.predict(x, verbose=0)
                dt = time.time() - t0
                times_per_image.append(dt)

            mean_t = float(np.mean(times_per_image))
            std_t  = float(np.std(times_per_image))
            all_avg_times.append(mean_t)
            w.writerow([grabbed, f"{mean_t:.6f}", f"{std_t:.6f}"])
            grabbed += 1

    overall_mean = float(np.mean(all_avg_times))
    overall_std  = float(np.std(all_avg_times))

    print(f"Inference time over {grabbed} images x {n_runs} runs:")
    print(f"  Mean : {overall_mean:.6f} s")
    print(f"  Std  : {overall_std:.6f} s")

    return overall_mean, overall_std


if __name__ == "__main__":
    VARIANT = "M"  # ganti S / M / L
    OUT     = f"effv2{VARIANT.lower()}"
    ROOT_DATASET = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"
    HASIL_DIR    = f"/content/drive/MyDrive/Database_Skripsi_Dhio/hasil/{OUT}"

    model = tf.keras.models.load_model(f"{HASIL_DIR}/{OUT}_best_phase1.keras")
    print("Model loaded:", model.name)

    _, test_ds, _, _, _, _ = build_datasets(root=ROOT_DATASET)

    mean_t, std_t = measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix=f"{HASIL_DIR}/{OUT}")

    with open(f"{HASIL_DIR}/{OUT}_inference_avg.json", "w") as f:
        json.dump({"mean_inference_time_sec": mean_t, "std_inference_time_sec": std_t}, f, indent=2)

    print(f"Selesai. Hasil disimpan di: {HASIL_DIR}")
# Out:
# Overwriting infer_time.py

# %%
# !python infer_time.py
# Out:
# 2026-04-16 16:46:18.848550: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776357978.870025   47760 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776357978.877209   47760 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776357978.895174   47760 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776357978.895219   47760 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776357978.895224   47760 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776357978.895227   47760 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-16 16:46:18.899889: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-04-16 16:46:25.964604: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1776357985.966135   47760 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Model loaded: functional_1
# Found 1800 files belonging to 30 classes.
# Found 1200 files belonging to 30 classes.
# 2026-04-16 16:46:40.136280: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-04-16 16:46:42.773209: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776358009.744344   47848 service.cc:152] XLA service 0x7eaf700d71c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776358009.744382   47848 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2026-04-16 16:46:50.111281: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1776358012.291551   47848 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-16 16:47:01.631561: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:01.817094: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:03.230407: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:03.444173: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:05.006148: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:05.229301: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:07.481270: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:07.658543: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:10.077239: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:10.287571: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1776358035.368891   47848 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-16 16:47:35.613491: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:35.748052: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:36.605272: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:36.740377: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:38.210257: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:38.359892: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:39.298776: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:47:39.473663: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# Inference time over 100 images x 10 runs:
#   Mean : 0.151758 s
#   Std  : 0.312260 s
# Selesai. Hasil disimpan di: /content/drive/MyDrive/Database_Skripsi_Dhio/hasil/effv2m

# %% [markdown]
# ## 10) Main (Skenario eksperimen S/M/L)

# %%
# %%writefile main.py
import json, os
import tensorflow as tf
from data import build_datasets
from model import build_model
from train import train
from eval import evaluate_on_test
from infer_time import measure_inference_time

# === PARAMETER SKENARIO ===

VARIANT       = "M"
EPOCHS_PHASE1 = 50
EPOCHS_PHASE2 = 0
OUT           = f"effv2{VARIANT.lower()}"
ROOT_DATASET  = "/content/drive/MyDrive/Database_Skripsi_Dhio/Dataset/Random"

tf.random.set_seed(42)

# === Data ===
train_ds, test_ds, num_classes, class_names, total_train, total_test = build_datasets(root=ROOT_DATASET)
class_names = tuple(class_names)
print(f"Classes ({num_classes}):", class_names)
print(f"Total train samples : ~{total_train}")
print(f"Total test samples  : ~{total_test}")
print(f"Augmentasi          : Online (RandAugment) — jumlah data tidak berubah")

# === Model ===
model, base = build_model(VARIANT, num_classes)
model.summary()

# === Train (Phase 1 saja) ===
model = train(
    model, base, train_ds,
    epochs_phase1=EPOCHS_PHASE1,
    epochs_phase2=EPOCHS_PHASE2,
    out_prefix=OUT
)

# === Evaluate (TEST) ===
metrics_test = evaluate_on_test(model, test_ds, class_names, out_prefix=OUT)
with open(f"{OUT}_test_metrics.json", "w") as f:
        json.dump(metrics_test, f, indent=2)

# === Inference time ===
mean_t, std_t = measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix=f"{HASIL_DIR}/{OUT}")

with open(f"{HASIL_DIR}/{OUT}_inference_avg.json", "w") as f:
    json.dump({"mean_inference_time_sec": mean_t, "std_inference_time_sec": std_t}, f, indent=2)

print("\nSelesai. File output tersimpan dengan prefix:", OUT)
# Out:
# Overwriting main.py

# %% [markdown]
# ## 11) Jalankan skenario (ubah VARIANT di `main.py` bila perlu)

# %%
# !python main.py
# Out:
# 2026-04-16 14:08:37.013573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1776348517.033109    5296 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1776348517.039470    5296 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1776348517.054559    5296 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776348517.054585    5296 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776348517.054588    5296 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1776348517.054590    5296 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-16 14:08:37.059143: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Found 1800 files belonging to 30 classes.
# 2026-04-16 14:08:50.697609: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# I0000 00:00:1776348530.700194    5296 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# Found 1200 files belonging to 30 classes.
# 2026-04-16 14:12:06.726780: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-04-16 14:14:11.393219: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Classes (30): ('Agathis borneensis - Damar Putih', 'Aquailaria beccariana - Gaharu', 'Cotylelobum Melanoxylum - Giam Tembaga', 'Diospyros Borneensis - Kayu Hitam', 'Dipterocarpus Confertus - Keruing Tempudau', 'Dipterocarpus tempehes - Keruing Asam', 'Durio dulcis - Lahung', 'Durio lanceolatus - Durian Anggang', 'Durio oxleyanus - kerantungan', 'Etlingera Balikpapanensis - Jahe Balikpapan', 'Eusideroxylon zwageri - Ulin', 'Hopea Mengerawan - damar cermin', 'Hopea Rudiformis - Merawan', 'Hopea dryobalanoides', 'Scorodocarpus Borneensis - Kayu Bawang', 'Shorea Agami - Meranti Putih', 'Shorea Beccariana - Meranti Merah Muda', 'Shorea Falciferoides ', 'Shorea Hopeifolia - Meranti Kuning', 'Shorea Macrophylla - Meranti Merah', 'Shorea Maxwelliana - Selangan Batu', 'Shorea Ovalis - Meranti Kelungkung', 'Shorea Pinanga - Tengkawang', 'Shorea Smithiana - Merebung', 'Shorea Stenoptera - Tengkawang Tungkul', 'Shorea inappendiculata - Selagan', 'Shorea pauciflora- Meranti', 'Vatica Pauciflora - Resak Laru', 'Vatica Sarawakensis - Resak Sarawak', 'Vatica Umbonata - Damar Tingkis')
# Total train samples : ~1824
# Total test samples  : ~1216
# Augmentasi          : Online (RandAugment) — jumlah data tidak berubah
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-m_notop.h5
# 214201816/214201816 ━━━━━━━━━━━━━━━━━━━━ 14s 0us/step
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 480, 480, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetv2-m (Functional)   │ (None, 15, 15, 1280)   │    53,150,388 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 30)             │        15,390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,821,650 (205.31 MB)
#  Trainable params: 671,262 (2.56 MB)
#  Non-trainable params: 53,150,388 (202.75 MB)
#
# === PHASE 1: Training HEAD saja (full backbone frozen) ===
# Backbone trainable: False
# Total trainable params: 671,262
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776348922.822825    5438 service.cc:152] XLA service 0x7ba3b0004010 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1776348922.822878    5438 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# 2026-04-16 14:15:24.531043: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1776348929.844860    5438 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-04-16 14:15:47.657742: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:47.843291: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:49.321790: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:49.536773: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:51.159587: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:51.383456: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:53.700750: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:53.877201: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:56.342047: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:15:56.555394: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1776348979.256001    5438 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-04-16 14:19:06.634735: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:06.776680: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:07.700305: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:07.850090: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:08.816924: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:08.968550: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:10.586049: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:10.745974: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:11.885986: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 14:19:12.080674: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#
# Epoch 1: accuracy improved from None to 0.14722, saving model to effv2m_best_phase1.keras
#
# Epoch 1: finished saving model to effv2m_best_phase1.keras
# 57/57 - 334s - 6s/step - accuracy: 0.1472 - loss: 3.2109 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 2/50
#
# Epoch 2: accuracy improved from 0.14722 to 0.36667, saving model to effv2m_best_phase1.keras
#
# Epoch 2: finished saving model to effv2m_best_phase1.keras
# 57/57 - 173s - 3s/step - accuracy: 0.3667 - loss: 2.7468 - precision: 0.0000e+00 - recall: 0.0000e+00
# Epoch 3/50
#
# Epoch 3: accuracy improved from 0.36667 to 0.49722, saving model to effv2m_best_phase1.keras
#
# Epoch 3: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.4972 - loss: 2.3240 - precision: 1.0000 - recall: 0.0017
# Epoch 4/50
#
# Epoch 4: accuracy improved from 0.49722 to 0.57444, saving model to effv2m_best_phase1.keras
#
# Epoch 4: finished saving model to effv2m_best_phase1.keras
# 57/57 - 175s - 3s/step - accuracy: 0.5744 - loss: 1.9902 - precision: 0.9531 - recall: 0.0339
# Epoch 5/50
#
# Epoch 5: accuracy improved from 0.57444 to 0.63611, saving model to effv2m_best_phase1.keras
#
# Epoch 5: finished saving model to effv2m_best_phase1.keras
# 57/57 - 174s - 3s/step - accuracy: 0.6361 - loss: 1.7038 - precision: 0.9659 - recall: 0.1100
# Epoch 6/50
#
# Epoch 6: accuracy improved from 0.63611 to 0.66944, saving model to effv2m_best_phase1.keras
#
# Epoch 6: finished saving model to effv2m_best_phase1.keras
# 57/57 - 176s - 3s/step - accuracy: 0.6694 - loss: 1.4938 - precision: 0.9758 - recall: 0.1789
# Epoch 7/50
#
# Epoch 7: accuracy improved from 0.66944 to 0.67000, saving model to effv2m_best_phase1.keras
#
# Epoch 7: finished saving model to effv2m_best_phase1.keras
# 57/57 - 175s - 3s/step - accuracy: 0.6700 - loss: 1.4630 - precision: 0.9778 - recall: 0.2206
# Epoch 8/50
#
# Epoch 8: accuracy improved from 0.67000 to 0.68667, saving model to effv2m_best_phase1.keras
#
# Epoch 8: finished saving model to effv2m_best_phase1.keras
# 57/57 - 174s - 3s/step - accuracy: 0.6867 - loss: 1.2936 - precision: 0.9538 - recall: 0.2983
# Epoch 9/50
#
# Epoch 9: accuracy improved from 0.68667 to 0.70333, saving model to effv2m_best_phase1.keras
#
# Epoch 9: finished saving model to effv2m_best_phase1.keras
# 57/57 - 174s - 3s/step - accuracy: 0.7033 - loss: 1.2292 - precision: 0.9621 - recall: 0.3383
# Epoch 10/50
#
# Epoch 10: accuracy improved from 0.70333 to 0.75111, saving model to effv2m_best_phase1.keras
#
# Epoch 10: finished saving model to effv2m_best_phase1.keras
# 57/57 - 178s - 3s/step - accuracy: 0.7511 - loss: 1.0789 - precision: 0.9639 - recall: 0.4156
# Epoch 11/50
#
# Epoch 11: accuracy improved from 0.75111 to 0.78444, saving model to effv2m_best_phase1.keras
#
# Epoch 11: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.7844 - loss: 0.9709 - precision: 0.9484 - recall: 0.4900
# Epoch 12/50
#
# Epoch 12: accuracy did not improve from 0.78444
# 57/57 - 177s - 3s/step - accuracy: 0.7794 - loss: 0.9340 - precision: 0.9444 - recall: 0.5006
# Epoch 13/50
#
# Epoch 13: accuracy improved from 0.78444 to 0.78889, saving model to effv2m_best_phase1.keras
#
# Epoch 13: finished saving model to effv2m_best_phase1.keras
# 57/57 - 180s - 3s/step - accuracy: 0.7889 - loss: 0.9278 - precision: 0.9524 - recall: 0.5228
# Epoch 14/50
#
# Epoch 14: accuracy improved from 0.78889 to 0.79500, saving model to effv2m_best_phase1.keras
#
# Epoch 14: finished saving model to effv2m_best_phase1.keras
# 57/57 - 181s - 3s/step - accuracy: 0.7950 - loss: 0.8534 - precision: 0.9514 - recall: 0.5650
# Epoch 15/50
#
# Epoch 15: accuracy did not improve from 0.79500
# 57/57 - 178s - 3s/step - accuracy: 0.7750 - loss: 0.8807 - precision: 0.9454 - recall: 0.5583
# Epoch 16/50
#
# Epoch 16: accuracy improved from 0.79500 to 0.80611, saving model to effv2m_best_phase1.keras
#
# Epoch 16: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.8061 - loss: 0.7990 - precision: 0.9393 - recall: 0.5933
# Epoch 17/50
#
# Epoch 17: accuracy did not improve from 0.80611
# 57/57 - 174s - 3s/step - accuracy: 0.7861 - loss: 0.8630 - precision: 0.9409 - recall: 0.5750
# Epoch 18/50
#
# Epoch 18: accuracy improved from 0.80611 to 0.82167, saving model to effv2m_best_phase1.keras
#
# Epoch 18: finished saving model to effv2m_best_phase1.keras
# 57/57 - 178s - 3s/step - accuracy: 0.8217 - loss: 0.7456 - precision: 0.9382 - recall: 0.6406
# Epoch 19/50
#
# Epoch 19: accuracy improved from 0.82167 to 0.85056, saving model to effv2m_best_phase1.keras
#
# Epoch 19: finished saving model to effv2m_best_phase1.keras
# 57/57 - 178s - 3s/step - accuracy: 0.8506 - loss: 0.6566 - precision: 0.9614 - recall: 0.6917
# Epoch 20/50
#
# Epoch 20: accuracy did not improve from 0.85056
# 57/57 - 174s - 3s/step - accuracy: 0.8411 - loss: 0.6646 - precision: 0.9525 - recall: 0.6800
# Epoch 21/50
#
# Epoch 21: accuracy did not improve from 0.85056
# 57/57 - 173s - 3s/step - accuracy: 0.8250 - loss: 0.6892 - precision: 0.9469 - recall: 0.6633
# Epoch 22/50
#
# Epoch 22: accuracy did not improve from 0.85056
# 57/57 - 173s - 3s/step - accuracy: 0.8328 - loss: 0.6803 - precision: 0.9570 - recall: 0.6683
# Epoch 23/50
#
# Epoch 23: accuracy did not improve from 0.85056
# 57/57 - 173s - 3s/step - accuracy: 0.8361 - loss: 0.6590 - precision: 0.9486 - recall: 0.6967
# Epoch 24/50
#
# Epoch 24: accuracy did not improve from 0.85056
# 57/57 - 173s - 3s/step - accuracy: 0.8489 - loss: 0.6063 - precision: 0.9502 - recall: 0.7211
# Epoch 25/50
#
# Epoch 25: accuracy did not improve from 0.85056
# 57/57 - 175s - 3s/step - accuracy: 0.8244 - loss: 0.6488 - precision: 0.9399 - recall: 0.7033
# Epoch 26/50
#
# Epoch 26: accuracy did not improve from 0.85056
# 57/57 - 174s - 3s/step - accuracy: 0.8161 - loss: 0.7012 - precision: 0.9502 - recall: 0.6683
# Epoch 27/50
#
# Epoch 27: accuracy did not improve from 0.85056
# 57/57 - 173s - 3s/step - accuracy: 0.8506 - loss: 0.5868 - precision: 0.9450 - recall: 0.7256
# Epoch 28/50
#
# Epoch 28: accuracy did not improve from 0.85056
# 57/57 - 174s - 3s/step - accuracy: 0.8433 - loss: 0.6124 - precision: 0.9562 - recall: 0.7278
# Epoch 29/50
#
# Epoch 29: accuracy improved from 0.85056 to 0.87056, saving model to effv2m_best_phase1.keras
#
# Epoch 29: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.8706 - loss: 0.5219 - precision: 0.9548 - recall: 0.7628
# Epoch 30/50
#
# Epoch 30: accuracy improved from 0.87056 to 0.89333, saving model to effv2m_best_phase1.keras
#
# Epoch 30: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.8933 - loss: 0.4763 - precision: 0.9617 - recall: 0.7950
# Epoch 31/50
#
# Epoch 31: accuracy did not improve from 0.89333
# 57/57 - 174s - 3s/step - accuracy: 0.8639 - loss: 0.5317 - precision: 0.9528 - recall: 0.7506
# Epoch 32/50
#
# Epoch 32: accuracy did not improve from 0.89333
# 57/57 - 174s - 3s/step - accuracy: 0.8878 - loss: 0.4586 - precision: 0.9525 - recall: 0.8022
# Epoch 33/50
#
# Epoch 33: accuracy did not improve from 0.89333
# 57/57 - 173s - 3s/step - accuracy: 0.8678 - loss: 0.5049 - precision: 0.9521 - recall: 0.7733
# Epoch 34/50
#
# Epoch 34: accuracy did not improve from 0.89333
# 57/57 - 174s - 3s/step - accuracy: 0.8700 - loss: 0.5233 - precision: 0.9528 - recall: 0.7511
# Epoch 35/50
#
# Epoch 35: accuracy improved from 0.89333 to 0.89889, saving model to effv2m_best_phase1.keras
#
# Epoch 35: finished saving model to effv2m_best_phase1.keras
# 57/57 - 178s - 3s/step - accuracy: 0.8989 - loss: 0.4150 - precision: 0.9521 - recall: 0.8178
# Epoch 36/50
#
# Epoch 36: accuracy did not improve from 0.89889
# 57/57 - 175s - 3s/step - accuracy: 0.8522 - loss: 0.5466 - precision: 0.9481 - recall: 0.7611
# Epoch 37/50
#
# Epoch 37: accuracy did not improve from 0.89889
# 57/57 - 174s - 3s/step - accuracy: 0.8933 - loss: 0.4283 - precision: 0.9578 - recall: 0.8072
# Epoch 38/50
#
# Epoch 38: accuracy did not improve from 0.89889
# 57/57 - 174s - 3s/step - accuracy: 0.8783 - loss: 0.4612 - precision: 0.9585 - recall: 0.7833
# Epoch 39/50
#
# Epoch 39: accuracy did not improve from 0.89889
# 57/57 - 176s - 3s/step - accuracy: 0.8878 - loss: 0.4535 - precision: 0.9572 - recall: 0.8067
# Epoch 40/50
#
# Epoch 40: accuracy did not improve from 0.89889
# 57/57 - 175s - 3s/step - accuracy: 0.8900 - loss: 0.4348 - precision: 0.9589 - recall: 0.8161
# Epoch 41/50
#
# Epoch 41: accuracy improved from 0.89889 to 0.90222, saving model to effv2m_best_phase1.keras
#
# Epoch 41: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.9022 - loss: 0.4020 - precision: 0.9535 - recall: 0.8194
# Epoch 42/50
#
# Epoch 42: accuracy did not improve from 0.90222
# 57/57 - 178s - 3s/step - accuracy: 0.8944 - loss: 0.4092 - precision: 0.9513 - recall: 0.8244
# Epoch 43/50
#
# Epoch 43: accuracy did not improve from 0.90222
# 57/57 - 177s - 3s/step - accuracy: 0.8911 - loss: 0.4195 - precision: 0.9545 - recall: 0.8150
# Epoch 44/50
#
# Epoch 44: accuracy improved from 0.90222 to 0.90333, saving model to effv2m_best_phase1.keras
#
# Epoch 44: finished saving model to effv2m_best_phase1.keras
# 57/57 - 176s - 3s/step - accuracy: 0.9033 - loss: 0.3985 - precision: 0.9589 - recall: 0.8289
# Epoch 45/50
#
# Epoch 45: accuracy did not improve from 0.90333
# 57/57 - 175s - 3s/step - accuracy: 0.8767 - loss: 0.4512 - precision: 0.9513 - recall: 0.8033
# Epoch 46/50
#
# Epoch 46: accuracy did not improve from 0.90333
# 57/57 - 174s - 3s/step - accuracy: 0.8939 - loss: 0.4218 - precision: 0.9560 - recall: 0.8083
# Epoch 47/50
#
# Epoch 47: accuracy improved from 0.90333 to 0.91500, saving model to effv2m_best_phase1.keras
#
# Epoch 47: finished saving model to effv2m_best_phase1.keras
# 57/57 - 176s - 3s/step - accuracy: 0.9150 - loss: 0.3762 - precision: 0.9647 - recall: 0.8500
# Epoch 48/50
#
# Epoch 48: accuracy did not improve from 0.91500
# 57/57 - 174s - 3s/step - accuracy: 0.8878 - loss: 0.4705 - precision: 0.9625 - recall: 0.7983
# Epoch 49/50
#
# Epoch 49: accuracy improved from 0.91500 to 0.92500, saving model to effv2m_best_phase1.keras
#
# Epoch 49: finished saving model to effv2m_best_phase1.keras
# 57/57 - 177s - 3s/step - accuracy: 0.9250 - loss: 0.3191 - precision: 0.9604 - recall: 0.8633
# Epoch 50/50
#
# Epoch 50: accuracy did not improve from 0.92500
# 57/57 - 176s - 3s/step - accuracy: 0.9139 - loss: 0.3658 - precision: 0.9629 - recall: 0.8511
#
# Phase 1 selesai dalam 148.9 menit
# Best accuracy: 0.9250
# Predicting test set...
# 37/38 ━━━━━━━━━━━━━━━━━━━━ 0s 780ms/step2026-04-16 16:44:28.727292: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:28.883949: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:30.021480: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:30.193631: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:31.403304: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:31.580458: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:33.370185: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:33.539603: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:35.355128: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-04-16 16:44:35.552057: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 79s 2s/step
# Saved: hasil/effv2m/effv2m_test_report.txt
# Saved: hasil/effv2m/effv2m_confusion_matrix.csv
# Saved: hasil/effv2m/effv2m_confusion_matrix.png
# TEST → Acc: 0.9700 | Prec(macro): 0.9710 | Rec(macro): 0.9700 | F1(macro): 0.9699
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Database_Skripsi_Dhio/main.py", line 45, in <module>
#     mean_t, std_t = measure_inference_time(model, test_ds, n_images=100, n_runs=10, out_prefix=f"{HASIL_DIR}/{OUT}")
#                                                                                                   ^^^^^^^^^
# NameError: name 'HASIL_DIR' is not defined

# %%
# !ls
# Out:
# data.py  Dataset_Citra	 eval.py	main.py   __pycache__	    train.py
# Dataset  Dataset_Mentah  infer_time.py	model.py  split_dataset.py
